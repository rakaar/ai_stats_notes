# %% [markdown]
# # Drift Diffusion Models

# %% [markdown]
#  # First passage time distribution, prob of hitting a bound
#  ![fptd.png](./images/fptd.png)~~

# %% [markdown]
# # First passage time distribution
# https://math.stackexchange.com/questions/1053294/density-of-first-hitting-time-of-brownian-motion-with-drift
#
# ![stack overflow](./images/fptd_short.png)

# %% [markdown]
# # Prob of hitting lower bound
# ![](./images/p_hit.png)

# %%
import numpy as np
from tqdm import tqdm
import multiprocessing as mp

import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
w = 0 # starting pt. 
a = 10 # up boundary 
v = 2 # drift vel
dt = 1e-5; dB = dt**0.5

# %%
def simulate_one_trial(w, a, v, dt, dB):
    DV = w # decision var
    t = 0 # time
    while DV <= a:
        DV += v*dt + np.random.normal(0,1)*dB # sigma = 1 implicit
        t += 1
    return t*dt

# %%
num_cores = mp.cpu_count()
with mp.Pool(processes=num_cores) as pool:
    RT_arr = pool.starmap(simulate_one_trial, [(w, a, v, dt, dB) for _ in range(500)])

# %%
plt.hist(RT_arr, density=True); plt.title('Simulated data hist');

# %%
def ftpd(a,c,t):
    return a*np.exp((-(a-c*t)**2)/(2*t))*(1/np.sqrt(2*np.pi*(t**3)))

# %%
t_vals = np.linspace(min(RT_arr), max(RT_arr), 1000)

prob_t = [ftpd(a,v,t) for t in t_vals]
# prob_t = [x/sum(prob_t) for x in prob_t]

plt.plot(t_vals, prob_t); plt.title('Theoretical');

# %%
plt.plot(t_vals, prob_t, label='Theoretical Distribution', color='red');
plt.hist(RT_arr, label='Simulated Data', density=True);

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 1000)
mu, std = norm.fit(RT_arr)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label = 'Smooth fitting for simulated data')

plt.legend();

# %% [markdown]
# BADS

# %%
from pybads import BADS

# %%
t = np.array(RT_arr.copy())

# %%
def target_func(params):
    a,c = params # upper bound, drift
    return np.sum(-np.log(a*np.exp((-(a-c*t)**2)/(2*t))*(1/np.sqrt(2*np.pi*(t**3)))))

# %%
# actual: a=10, c = 2. 
lower_bounds = np.array([1, -5]) 
upper_bounds = np.array([15, 5])
plausible_lower_bounds = np.array([2, 1e-3])
plausible_upper_bounds = np.array([13, 5])
x0 = np.array([2.2, 0.1]);

# %%
options = {
    "max_iter": 2000, 
    "max_fun_evals": 2000
}

bads = BADS(target_func, x0, lower_bounds, upper_bounds, plausible_lower_bounds, plausible_upper_bounds, options=options)
optimize_result = bads.optimize()
# Out:
# bads:TooCloseBounds: For each variable, hard and plausible bounds should not be too close. Moving plausible bounds.
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         1410.59               1                                 Uncertainty test
#      0           6         819.416               1         Initial mesh            Initial points
#      0           9         819.416             0.5         Refine grid             Train
#      1          17         819.416            0.25         Refine grid             Train
#      2          18         744.677            0.25     Successful search (ES-ell)
#      2          19         744.487            0.25     Successful search (ES-ell)
#      2          20         744.487            0.25     Incremental search (ES-wcm)
#      2          22         744.484            0.25     Incremental search (ES-wcm)
#      2          25         744.483            0.25     Incremental search (ES-ell)
#      2          29         744.483           0.125         Refine grid             Train
#      3          33         744.483           0.125     Incremental search (ES-ell)
#      3          37         744.483          0.0625         Refine grid
#      4          38         744.483          0.0625     Incremental search (ES-ell)
#      4          45         744.483         0.03125         Refine grid
#      5          53         744.483       0.0078125         Refine grid             Train
#      6          61         744.483      0.00195312         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: 744.4829513007371

# %%
x_min = optimize_result['x']
x_min# 10, 2
# Out:
# array([10.07936287,  2.01076707])

# %% [markdown]
# # Dynesty

# %%
from dynesty import NestedSampler
      
from dynesty import plotting as dyplot

# %%
def log_like(params):
    a,c = params # upper bound, drift
    return np.sum(np.log(a*np.exp((-(a-c*t)**2)/(2*t))*(1/np.sqrt(2*np.pi*(t**3)))))

# %%
def transform_random_number(u, a, b):
    return (b-a)*u + a

# %%
def prior_transform(u):
    # u ~ uniform [0,1]
    priors = np.array(u)

    # a: 0 to 20
    priors[0] =  transform_random_number(u[0], 0.1, 20)


    # c: -5 to 5
    priors[1] = transform_random_number(u[1], -5, 5)

    return priors

# %%
ndim = 2
# sampler = NestedSampler(log_likelihood, prior_transform, ndim)
sampler = NestedSampler(log_like, prior_transform, ndim, nlive = 1000)

# %%
sampler.run_nested()
# Out:
# 8635it [00:08, 1054.72it/s, +1000 | bound: 6 | nc: 1 | ncall: 44658 | eff(%): 22.069 | loglstar:   -inf < -744.484 <    inf | logz: -752.884 +/-  0.087 | dlogz:  0.001 >  1.009]

# %%
results = sampler.results
results.samples[:,0].mean(), results.samples[:,1].mean() # 10, 2
# Out:
# (10.151566577396059, 1.768018450197534)

# %%
samples = results.samples
print(samples.shape) # (10886, 2)

weights = results.importance_weights()
print(weights.shape)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot mu distribution
axes[0].hist(samples[:, 0], weights=weights, bins=20) # Use plt.hist here
axes[0].set_xlabel('a')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Posterior Distribution of a')

# Plot sigma distribution
axes[1].hist(samples[:, 1], weights=weights, bins=20) # Use plt.hist here
axes[1].set_xlabel('c')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Posterior Distribution of c')

# Plot joint distribution of mu and sigma
dyplot.cornerpoints(results, kde=True, fig=(fig, axes[2]), truths=[10,2], truth_color='black')
axes[2].set_xlabel('a')
axes[2].set_ylabel('c')
axes[2].set_title('Joint Posterior Distribution of a and c')
axes[2].set_yticks(np.arange(-5, 6, 1))
axes[2].set_ylim(-5, 5)

plt.tight_layout()
plt.show()
# Out:
# (9635, 2)
# (9635,)

# %% [markdown]
# # VBMC

# %%
from pyvbmc import VBMC
from scipy import stats

# %%
a_prior = stats.uniform(0.1,20)
c_prior = stats.uniform(-5, 10);

# %%
def log_prior(params):
    a, c = params
    log_prior_a = a_prior.logpdf(a)
    log_prior_c = c_prior.logpdf(c)
    return log_prior_a + log_prior_c

# %%
def log_joint(params):
    return log_like(params) + log_prior(params)

# %%
vbmc = VBMC(log_joint, x0, lower_bounds, upper_bounds, plausible_lower_bounds, plausible_upper_bounds)
# bads = BADS(target_func, x0, lower_bounds, upper_bounds, plausible_lower_bounds, plausible_upper_bounds, options=options)
vp, results = vbmc.optimize()
# Out:
# Reshaping x0 to row vector.
# Reshaping lower bounds to (1, 2).
# Reshaping upper bounds to (1, 2).
# Reshaping plausible lower bounds to (1, 2).
# Reshaping plausible upper bounds to (1, 2).
# Casting lower bounds to floating point.
# Casting upper bounds to floating point.
# Casting plausible upper bounds to floating point.
# vbmc:TooCloseBounds: For each variable, hard and plausible bounds should not be too close. Moving plausible bounds.
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10        -552.80      1533.38 79868867214726848.00        2        inf     start warm-up
#      1         15        -752.28         0.68       112.22        2        inf
#      2         20        -753.68         0.05         1.60        2       42.5
#      3         25        -753.65         0.00         0.01        2      0.319
#      4         30        -753.65         0.00         0.00        2     0.0418
#      5         35        -753.66         0.00         0.00        2     0.0572
#      6         40        -753.64         0.00         0.00        2      0.104
#      7         45        -753.67         0.00         0.00        2       0.15     end warm-up
#      8         50        -753.67         0.00         0.02        2      0.547
#      9         55        -753.66         0.00         0.04        2       1.05
#     10         60        -753.59         0.00         0.07        3       1.81
#     11         65        -753.66         0.00         0.15        4        3.7
#     12         70        -753.61         0.00         0.08        4       2.17
#     13         75        -753.51         0.00         0.15        4       3.95
#     14         80        -753.91         0.00         0.25        5       7.25
#     15         85        -753.59         0.00         0.15        5       4.56
#     16         90        -753.48         0.00         0.39        5       9.57
#     17         95        -753.31         0.00         0.24        6       6.23
#     18        100        -753.59         0.00         0.06        7       2.32
#     19        100        -753.00         0.00         0.35        7       10.2     rotoscale
#     20        105        -753.00         0.00         0.00        8     0.0108
#     21        110        -753.00         0.00         0.00       11     0.0091
#     22        115        -753.00         0.00         0.00       14     0.0116
#     23        120        -753.00         0.00         0.00       16      0.014
#     24        125        -753.00         0.00         0.00       13     0.0151
#     25        130        -752.99         0.00         0.00       12     0.0148     rotoscale, undo rotoscale
#     26        135        -753.01         0.00         0.00       12     0.0477
#     27        140        -752.99         0.00         0.00       12     0.0548
#     28        145        -753.00         0.00         0.00       13     0.0222
#     29        150        -753.00         0.00         0.00       12     0.0266     stable
#    inf        150        -753.00         0.00         0.00       50     0.0266     finalize
# Inference terminated: variational solution stable for options.tol_stable_count fcn evaluations.
# Estimated ELBO: -752.999 +/-0.000.

# %%
vp.plot();

# %%
a_c, _ = vp.sample(int(3e5))
a_post = a_c[:,0]
c_post = a_c[:,1]

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(a_post, bins=20)
plt.title(f'Posterior Distribution of a (mean = {np.mean(a_post):.2f})')
plt.xlabel('a')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(c_post, bins=20)
plt.title(f'Posterior Distribution of c (mean = {np.mean(c_post):.2f})')
plt.xlabel('c')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3 Param model

# %%
starting_pt = 5 # starting pt
a = 10 # up boundary 
w = starting_pt/a # starting pt relative to boundary
v = 1 # drift vel
dt = 1e-5; dB = dt**0.5

# %%
def simulate_one_trial(w, a, v, dt, dB):
    DV = w # decision var
    t = 0 # time
    while DV <= a:
        DV += v*dt + np.random.normal(0,1)*dB # sigma = 1 implicit
        t += 1
    return t*dt

# %%
num_cores = mp.cpu_count()
with mp.Pool(processes=num_cores) as pool:
    RT_arr = pool.starmap(simulate_one_trial, [(starting_pt, a, v, dt, dB) for _ in range(500)])

# %%
plt.hist(RT_arr, density=True); plt.title('Simulated data hist');

# %%
def ftpd_3(v,a,w,t):
    term1 = ((np.pi)/(a**2))*np.exp(v*a*w-(v**2 * t/2))
    term2 = [ k * np.exp(-(k**2 * np.pi**2 * t)/(2 * a**2)) * np.sin(k*np.pi*w) for k in range(1,10) ]
    return term1*np.sum(term2)

# %%
t_vals = np.linspace(min(RT_arr), max(RT_arr), 100)

prob_t = [ftpd_3(v, a, 1-w, t) for t in t_vals]
# prob_t = [x/sum(prob_t) for x in prob_t]

plt.plot(t_vals, prob_t); plt.title('Theoretical');

# %%
plt.plot(t_vals, prob_t, label='Theoretical Distribution', color='red');
plt.hist(RT_arr, label='Simulated Data', density=True);

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 1000)
mu, std = norm.fit(RT_arr)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label = 'Smooth fitting for simulated data')

from scipy.stats import gaussian_kde
kde = gaussian_kde(RT_arr)
x = np.linspace(min(RT_arr), max(RT_arr), 1000)
plt.plot(x, kde(x), 'g', linewidth=2, label = 'KDE for simulated data')


plt.legend();

# %% [markdown]
# # Dynesty on 3 params

# %%
t = np.array(RT_arr.copy())

# %%
def log_like(params):
    v,a,w = params
    term1 = ((np.pi)/(a**2))*np.exp(v*a*w-(v**2 * t/2))
    term2 = [ k * np.exp(-(k**2 * np.pi**2 * t)/(2 * a**2)) * np.sin(k*np.pi*w) for k in range(1,10) ]
    # plt.plot(term1*np.sum(term2));
    return np.sum(np.log(term1*np.sum(term2)))

# %%
def prior_transform(u):
    # u ~ uniform [0,1]
    priors = np.array(u)

    # v:  1
    priors[0] =  transform_random_number(u[0], 0.5, 3)


    # a:  10
    priors[1] = transform_random_number(u[1], 7, 13)

    
    # w:  0.5
    priors[2] = transform_random_number(u[2], 0.3, 0.7)

    return priors

# %%
ndim = 3
# sampler = NestedSampler(log_likelihood, prior_transform, ndim)
sampler = NestedSampler(log_like, prior_transform, ndim, nlive = 2500)

# %%
sampler.run_nested()
# Out:
# 43795it [01:18, 557.66it/s, +2500 | bound: 26 | nc: 1 | ncall: 186999 | eff(%): 25.092 | loglstar:   -inf < 2909.411 <    inf | logz: 2890.580 +/-  0.118 | dlogz:  0.001 >  2.509]

# %%
results = sampler.results
results.samples[:,0].mean(), results.samples[:,1].mean(),results.samples[:,2].mean()  # 1, 10, 0.5
# Out:
# (1.5135354720365093, 12.340587958141933, 0.6603184989466295)

# %%
samples = results.samples
print(samples.shape) # (10886, 3)

weights = results.importance_weights()
print(weights.shape)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot v distribution
axes[0].hist(samples[:, 0], weights=weights, bins=20) # Use plt.hist here
axes[0].set_xlabel('v')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Posterior Distribution of v')

# Plot a distribution
axes[1].hist(samples[:, 1], weights=weights, bins=20) # Use plt.hist here
axes[1].set_xlabel('a')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Posterior Distribution of a')

# Plot w distribution
axes[2].hist(samples[:, 2], weights=weights, bins=20) # Use plt.hist here
axes[2].set_xlabel('w')
axes[2].set_ylabel('Probability Density')
axes[2].set_title('Posterior Distribution of w')

plt.tight_layout()
plt.show()
# Out:
# (46295, 3)
# (46295,)

# %% [markdown]
# # BADS

# %%
def target_func(params):
    v,a,w = params
    term1 = ((np.pi)/(a**2))*np.exp(v*a*w-(v**2 * t/2))
    term2 = [ k * np.exp(-(k**2 * np.pi**2 * t)/(2 * a**2)) * np.sin(k*np.pi*w) for k in range(1,10) ]
    # plt.plot(term1*np.sum(term2));
    return np.sum(-np.log(term1*np.sum(term2)))

# %%
# actual: v,a,w: 1, 10, 0.5. 
lower_bounds = np.array([0.1, 7, 0.2]) 
upper_bounds = np.array([3, 13, 0.8])
plausible_lower_bounds = np.array([0.2, 8, 0.25])
plausible_upper_bounds = np.array([2.8, 12.5, 0.75])
x0 = np.array([0.25, 12, 0.7]);

# %%
options = {
    "max_iter": 2000, 
    "max_fun_evals": 5000
}

bads = BADS(target_func, x0, lower_bounds, upper_bounds, plausible_lower_bounds, plausible_upper_bounds, options=options)
optimize_result = bads.optimize()
# Out:
# Variables (index) internally transformed to log coordinates: [[0 0]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         -529.91               1                                 Uncertainty test
#      0           6         -1939.2               1         Initial mesh            Initial points
#      0          11        -2060.04               1       Successful poll           Train
#      1          15        -2275.84               1     Successful search (ES-wcm)
#      1          18        -2654.73               1     Successful search (ES-wcm)
#      1          19        -3397.72               1     Successful search (ES-wcm)
#      1          22           -3409               1     Successful search (ES-wcm)
#      1          30           -3409             0.5         Refine grid             Train
#      2          34        -3410.01             0.5     Successful search (ES-ell)
#      2          41        -3410.01            0.25         Refine grid             Train
#      3          43        -3410.01            0.25     Incremental search (ES-ell)
#      3          49        -3410.01           0.125         Refine grid             Train
#      4          57        -3410.01          0.0625         Refine grid             Train
#      5          65        -3410.01        0.015625         Refine grid             Train
#      6          66        -3410.08        0.015625     Successful search (ES-ell)
#      6          73        -3410.09        0.015625     Successful search (ES-wcm)
#      6          81        -3410.09       0.0078125         Refine grid             Train
#      7          89        -3410.09      0.00390625         Refine grid             Train
#      8          97        -3410.09      0.00195312         Refine grid             Train
#      9         105        -3410.09     0.000488281         Refine grid             Train
#     10         113        -3410.09      0.00012207         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: -3410.089906979715

# %%
x_min = optimize_result['x']
x_min #1, 10, 0.5
# Out:
# array([ 1.83427031, 12.9999997 ,  0.79999995])

# %% [markdown]
# # VBMC

# %%
t = np.array(RT_arr.copy())

# %%
a_prior = stats.uniform(8,12)
v_prior = stats.uniform(0.1, 2)
w_prior = stats.uniform(0.1,0.9)

# %%
def log_prior(params):
    v,a,w = params
    log_prior_v = v_prior.logpdf(v)
    log_prior_a = a_prior.logpdf(a)
    log_prior_w = w_prior.logpdf(w)
    print('priors ',  log_prior_v, log_prior_a, 'log prior w =',log_prior_w, 'w=',w)
    return log_prior_v + log_prior_a + log_prior_w

# %%
def log_like(params):
    v,a,w = params
    term1 = ((np.pi)/(a**2))*np.exp(v*a*w-(v**2 * t/2))
    term2 = [ k * np.exp(-(k**2 * np.pi**2 * t)/(2 * a**2)) * np.sin(k*np.pi*w) for k in range(1,10) ]
    print('likeli, ', np.sum(np.log(term1*np.sum(term2))))
    return np.sum(np.log(term1*np.sum(term2)))

# %%
def log_joint(params):
    print('joint ', log_like(params) + log_prior(params))
    return log_like(params) + log_prior(params)

# %%
# actual: v,a,w: 1, 10, 0.5. 
lower_bounds = np.array([0.5, 8, 0.2]) 
upper_bounds = np.array([2, 12, 0.8])
plausible_lower_bounds = np.array([0.6, 9, 0.25])
plausible_upper_bounds = np.array([1.9, 11, 0.75])



x0 = np.array([0.7, 9.1, 0.7])

# %%
vbmc = VBMC(log_joint, x0, lower_bounds, upper_bounds, plausible_lower_bounds, plausible_upper_bounds)
# bads = BADS(target_func, x0, lower_bounds, upper_bounds, plausible_lower_bounds, plausible_upper_bounds, options=options)
vp, results = vbmc.optimize()
# Out:
# Reshaping x0 to row vector.
# Reshaping lower bounds to (1, 3).
# Reshaping upper bounds to (1, 3).
# Reshaping plausible lower bounds to (1, 3).
# Reshaping plausible upper bounds to (1, 3).
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
# likeli,  1962.566130206174
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7
# joint  1959.493436891484
# likeli,  1962.566130206174
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7
# likeli,  2048.479404667347
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.5621567166571233
# joint  2045.4067113526569
# likeli,  2048.479404667347
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.5621567166571233
# likeli,  1989.1875319903434
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.4452113393024967
# joint  1986.1148386756533
# likeli,  1989.1875319903434
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.4452113393024967
# likeli,  2262.8034891832694
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7335628281817972
# joint  2259.730795868579
# likeli,  2262.8034891832694
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7335628281817972
# likeli,  1922.1970262325995
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.36326353934777966
# joint  1919.1243329179094
# likeli,  1922.1970262325995
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.36326353934777966
# likeli,  900.1660411158473
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.3644195416860929
# joint  897.0933478011572
# likeli,  900.1660411158473
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.3644195416860929
# likeli,  -493.9195552355771
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.31266586164262167
# joint  -496.9922485502672
# likeli,  -493.9195552355771
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.31266586164262167
# likeli,  2258.653089699874
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7160176222726964
# joint  2255.5803963851836
# likeli,  2258.653089699874
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7160176222726964
# likeli,  896.632936931299
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.4678353807543075
# joint  893.5602436166089
# likeli,  896.632936931299
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.4678353807543075
# likeli,  2301.073500284865
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.677017391744845
# joint  2298.000806970175
# likeli,  2301.073500284865
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.677017391744845
#      0         10        2560.73       104.08          inf        2        inf     start warm-up
# likeli,  2764.4059801587127
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7881560454984964
# joint  2761.3332868440225
# likeli,  2764.4059801587127
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7881560454984964
# likeli,  2727.6241235527964
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7814069062343585
# joint  2724.551430238106
# likeli,  2727.6241235527964
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7814069062343585
# likeli,  2751.8200361098015
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7812720843699943
# joint  2748.7473427951113
# likeli,  2751.8200361098015
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7812720843699943
# likeli,  2871.2748775838254
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7815940575431264
# joint  2868.202184269135
# likeli,  2871.2748775838254
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7815940575431264
# likeli,  2875.498042982698
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7814445773377718
# joint  2872.4253496680076
# likeli,  2875.498042982698
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7814445773377718
#      1         15        2913.89        11.16       533.14        2        inf
# likeli,  3043.357614080228
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7928793656435935
# joint  3040.2849207655377
# likeli,  3043.357614080228
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7928793656435935
# likeli,  3017.2721975500226
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.788525967650082
# joint  3014.1995042353324
# likeli,  3017.2721975500226
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.788525967650082
# likeli,  3033.076876644859
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7949127208410602
# joint  3030.004183330169
# likeli,  3033.076876644859
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7949127208410602
# likeli,  3025.694768550895
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7933178869616626
# joint  3022.6220752362046
# likeli,  3025.694768550895
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7933178869616626
# likeli,  3070.169689122194
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999939999998755
# joint  3067.096995807504
# likeli,  3070.169689122194
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999939999998755
#      2         20        3215.53       132.52    203536.31        2   3.92e+06
# likeli,  3066.3326019061615
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999070050353738
# joint  3063.2599085914712
# likeli,  3066.3326019061615
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999070050353738
# likeli,  3081.509256263769
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998154137427846
# joint  3078.436562949079
# likeli,  3081.509256263769
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998154137427846
# likeli,  3075.4438544413233
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998451992179021
# joint  3072.371161126633
# likeli,  3075.4438544413233
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998451992179021
# likeli,  3068.188089832518
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996681799287568
# joint  3065.115396517828
# likeli,  3068.188089832518
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996681799287568
# likeli,  3076.287585770435
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998854926934054
# joint  3073.2148924557446
# likeli,  3076.287585770435
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998854926934054
#      3         25        3075.79        32.66       861.67        2   1.72e+04
# likeli,  3072.387968212925
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7984621001029977
# joint  3069.3152748982347
# likeli,  3072.387968212925
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7984621001029977
# /home/rka/.local/lib/python3.10/site-packages/cma/evolution_strategy.py:3829: RuntimeWarning: invalid value encountered in scalar subtract
#   current_fitness_range < opts['tolfunrel'] * (es.fit.median0 - es.fit.median_min),
# /home/rka/.local/lib/python3.10/site-packages/cma/evolution_strategy.py:3829: RuntimeWarning: invalid value encountered in scalar multiply
#   current_fitness_range < opts['tolfunrel'] * (es.fit.median0 - es.fit.median_min),
# likeli,  3075.6940033899673
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999939999255439
# joint  3072.621310075277
# likeli,  3075.6940033899673
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999939999255439
# likeli,  3076.7200902307427
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7994928715922067
# joint  3073.6473969160525
# likeli,  3076.7200902307427
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7994928715922067
# likeli,  3082.1312946646685
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999939999286749
# joint  3079.0586013499783
# likeli,  3082.1312946646685
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999939999286749
# likeli,  3080.4252646999266
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799310931329674
# joint  3077.3525713852364
# likeli,  3080.4252646999266
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799310931329674
#      4         30        3062.91         8.13        40.50        2        849
# likeli,  3082.7138532596528
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999797289056807
# joint  3079.6411599449625
# likeli,  3082.7138532596528
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999797289056807
# likeli,  3080.5624363238167
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7994716193923266
# joint  3077.4897430091264
# likeli,  3080.5624363238167
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7994716193923266
# likeli,  3080.8780622841614
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996112168991929
# joint  3077.805368969471
# likeli,  3080.8780622841614
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996112168991929
# likeli,  3078.921984832912
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799651387071775
# joint  3075.849291518222
# likeli,  3078.921984832912
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799651387071775
# likeli,  3083.358953291524
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999771692356898
# joint  3080.2862599768337
# likeli,  3083.358953291524
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999771692356898
#      5         35        3063.08         0.40         0.63        2       14.1
# likeli,  3082.1565520750364
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999307530917217
# joint  3079.083858760346
# likeli,  3082.1565520750364
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999307530917217
# likeli,  3082.0250303800412
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997482341338826
# joint  3078.952337065351
# likeli,  3082.0250303800412
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997482341338826
# likeli,  3081.0998104412274
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998279069684886
# joint  3078.027117126537
# likeli,  3081.0998104412274
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998279069684886
# likeli,  3081.7586845951796
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999808663597161
# joint  3078.6859912804894
# likeli,  3081.7586845951796
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999808663597161
# likeli,  3082.166126752814
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998943334279454
# joint  3079.0934334381236
# likeli,  3082.166126752814
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998943334279454
#      6         40        3063.29         0.02         0.12        2       3.02
# likeli,  3080.3626551695374
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995606288083528
# joint  3077.289961854847
# likeli,  3080.3626551695374
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995606288083528
# likeli,  3082.0116711469755
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999664918038025
# joint  3078.938977832285
# likeli,  3082.0116711469755
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999664918038025
# likeli,  3080.5106274917734
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799944076451935
# joint  3077.437934177083
# likeli,  3080.5106274917734
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799944076451935
# likeli,  3082.8968004497874
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999568234623753
# joint  3079.824107135097
# likeli,  3082.8968004497874
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999568234623753
# likeli,  3082.9670886232225
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999878457667506
# joint  3079.8943953085322
# likeli,  3082.9670886232225
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999878457667506
#      7         45        3063.30         0.03         0.01        2      0.358
# likeli,  3082.409929718623
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998109519248482
# joint  3079.337236403933
# likeli,  3082.409929718623
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998109519248482
# likeli,  3080.3414372223037
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799788520565111
# joint  3077.2687439076135
# likeli,  3080.3414372223037
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799788520565111
# likeli,  3080.1493199336664
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995300653794541
# joint  3077.076626618976
# likeli,  3080.1493199336664
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995300653794541
# likeli,  3081.8969895960663
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998275146830092
# joint  3078.824296281376
# likeli,  3081.8969895960663
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998275146830092
# likeli,  3082.46758332765
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998061875643481
# joint  3079.39489001296
# likeli,  3082.46758332765
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998061875643481
#      8         50        3063.31         0.01         0.01        2      0.286
# likeli,  3082.8826732488214
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799857404380037
# joint  3079.809979934131
# likeli,  3082.8826732488214
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799857404380037
# likeli,  3079.987995814803
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999143992558491
# joint  3076.915302500113
# likeli,  3079.987995814803
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999143992558491
# likeli,  3080.270599956473
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7993479319777503
# joint  3077.1979066417825
# likeli,  3080.270599956473
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7993479319777503
# likeli,  3081.9439790657443
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996143832641367
# joint  3078.871285751054
# likeli,  3081.9439790657443
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996143832641367
# likeli,  3078.8278953012023
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7990922626602481
# joint  3075.755201986512
# likeli,  3078.8278953012023
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7990922626602481
#      9         55        3063.37         0.00         0.01        2      0.413
# likeli,  3082.6432489556432
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997799222573332
# joint  3079.570555640953
# likeli,  3082.6432489556432
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997799222573332
# likeli,  3080.107585303177
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998794351008129
# joint  3077.034891988487
# likeli,  3080.107585303177
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998794351008129
# likeli,  3081.9652187436936
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999932308585251
# joint  3078.8925254290034
# likeli,  3081.9652187436936
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999932308585251
# likeli,  3081.341284814521
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998120247225264
# joint  3078.2685914998306
# likeli,  3081.341284814521
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998120247225264
# likeli,  3082.6202113786444
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999093145831739
# joint  3079.547518063954
# likeli,  3082.6202113786444
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999093145831739
#     10         60        3063.26         0.00         0.01        2      0.494     end warm-up
# likeli,  3077.7590299989743
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7992532604866471
# joint  3074.686336684284
# likeli,  3077.7590299989743
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7992532604866471
# likeli,  3078.0783503469647
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997779259425755
# joint  3075.0056570322745
# likeli,  3078.0783503469647
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997779259425755
# likeli,  3082.2538551151933
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999792398943473
# joint  3079.181161800503
# likeli,  3082.2538551151933
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999792398943473
# likeli,  3081.792540278185
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996999202590598
# joint  3078.7198469634945
# likeli,  3081.792540278185
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996999202590598
# likeli,  3081.662528309623
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996411799785239
# joint  3078.589834994933
# likeli,  3081.662528309623
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996411799785239
#     11         65        3063.34         0.00         0.01        2      0.449
# likeli,  3081.8116301610917
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997782930424233
# joint  3078.7389368464014
# likeli,  3081.8116301610917
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997782930424233
# likeli,  3082.772360820041
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998934073254531
# joint  3079.6996675053506
# likeli,  3082.772360820041
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998934073254531
# likeli,  3077.4834690690514
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.79882568180594
# joint  3074.410775754361
# likeli,  3077.4834690690514
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.79882568180594
# likeli,  3081.939329185834
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799789809525312
# joint  3078.866635871144
# likeli,  3081.939329185834
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799789809525312
# likeli,  3081.716348501839
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999010163148423
# joint  3078.643655187149
# likeli,  3081.716348501839
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999010163148423
#     12         70        3063.33         0.00         0.02        2      0.398
# likeli,  3080.871756367966
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998036467702874
# joint  3077.799063053276
# likeli,  3080.871756367966
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998036467702874
# likeli,  3078.997251634239
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995696398104639
# joint  3075.924558319549
# likeli,  3078.997251634239
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995696398104639
# likeli,  3081.859879595231
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999137563791556
# joint  3078.787186280541
# likeli,  3081.859879595231
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999137563791556
# likeli,  3082.6388731260877
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999506222092387
# joint  3079.5661798113974
# likeli,  3082.6388731260877
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999506222092387
# likeli,  3080.6777186702266
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997855720640763
# joint  3077.6050253555363
# likeli,  3080.6777186702266
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997855720640763
#     13         75        3063.36         0.00         0.01        5      0.397
# likeli,  3079.9914786893823
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996173457738247
# joint  3076.918785374692
# likeli,  3079.9914786893823
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996173457738247
# likeli,  3081.715469402424
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997667753609075
# joint  3078.6427760877336
# likeli,  3081.715469402424
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997667753609075
# likeli,  3081.7716685729474
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998065209192717
# joint  3078.698975258257
# likeli,  3081.7716685729474
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998065209192717
# likeli,  3082.074724208691
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998823755447395
# joint  3079.0020308940007
# likeli,  3082.074724208691
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998823755447395
# likeli,  3083.2819998618725
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999936648982349
# joint  3080.209306547182
# likeli,  3083.2819998618725
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999936648982349
#     14         80        3063.37         0.00         0.00        8     0.0706     rotoscale, undo rotoscale
# likeli,  3078.1456948111254
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799284448082094
# joint  3075.073001496435
# likeli,  3078.1456948111254
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.799284448082094
# likeli,  3080.435923022415
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995518159261332
# joint  3077.3632297077247
# likeli,  3080.435923022415
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995518159261332
# likeli,  3081.7447706306107
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999938648492446
# joint  3078.6720773159204
# likeli,  3081.7447706306107
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999938648492446
# likeli,  3081.403660688982
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996131087222
# joint  3078.330967374292
# likeli,  3081.403660688982
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7996131087222
# likeli,  3081.2965594467755
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998853743859702
# joint  3078.2238661320853
# likeli,  3081.2965594467755
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998853743859702
#     15         85        3063.37         0.00         0.00       11     0.0252
# likeli,  3079.823478154347
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999779889028105
# joint  3076.7507848396567
# likeli,  3079.823478154347
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7999779889028105
# likeli,  3081.7665279504085
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997975853070565
# joint  3078.6938346357183
# likeli,  3081.7665279504085
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997975853070565
# likeli,  3080.7667323074847
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998140549263404
# joint  3077.6940389927945
# likeli,  3080.7667323074847
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7998140549263404
# likeli,  3080.4707304213025
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997186674584764
# joint  3077.3980371066123
# likeli,  3080.4707304213025
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7997186674584764
# likeli,  3080.36828038088
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995393117801983
# joint  3077.29558706619
# likeli,  3080.36828038088
# priors  -0.6931471805599453 -2.4849066497880004 log prior w = 0.10536051565782628 w= 0.7995393117801983
#     16         90        3063.36         0.00         0.01       11      0.158     stable
#    inf         90        3063.40         0.00         0.02       50      0.158     finalize
# Inference terminated: variational solution stable for options.tol_stable_count fcn evaluations.
# Estimated ELBO: 3063.397 +/-0.004.

# %%
vp.plot()

# %%
a_c, _ = vp.sample(int(3e5))
v_post = a_c[:,0]
a_post = a_c[:,1]
w_post = a_c[:,2]

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.hist(v_post, bins=20)
plt.title(f'Posterior Distribution of v (mean = {np.mean(v_post):.2f})')
plt.xlabel('v')
plt.ylabel('Frequency')

plt.subplot(1, 3, 2)
plt.hist(a_post, bins=20)
plt.title(f'Posterior Distribution of a (mean = {np.mean(a_post):.2f})')
plt.xlabel('a')
plt.ylabel('Frequency')

plt.subplot(1, 3, 3)
plt.hist(w_post, bins=20)
plt.title(f'Posterior Distribution of w (mean = {np.mean(w_post):.2f})')
plt.xlabel('w')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
